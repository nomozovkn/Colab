# %% [markdown]
# <a href="https://colab.research.google.com/github/nomozovkn/Colab/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# O'zbekiston aholisi va Migratsiya Statistikas

# %%
# 1-bosqich: XML faylni Colabga yuklash
#   - UNdata saytidan O‘zbekiston bo‘yicha ma’lumotni XML formatda yukladik.
#   - Fayl nomi: '1-013-0032.xml'

# 2-bosqich: XML faylni o‘qish va DataFramega aylantirish
#   - pandas.read_xml() yordamida faylni o‘qidik.
#   - Barcha teglarni tekshirib, kerakli ustunlarni tanladik.

# 3-bosqich: Keraksiz ustunlarni olib tashlash va ma’lumotlarni tozalash
#   - NaN qiymatlar yoki bo‘sh elementlar o‘rnini tekshirdik.
#   - Ma’lumotlarni raqamli formatga o‘tkazdik (to_numeric).

# 4-bosqich: Yillar bo‘yicha filtrlar va tahlil
#   - Har bir yil bo‘yicha NetMigration, RefugeePopulation va PersonalRemittancesni ajratdik.
#   - DataFrame tayyor va tozalangan ko‘rinishga keldi.

import pandas as pd

# 2-bosqich kodi misol
df = pd.read_xml("1-013-0032.xml")

# 3-bosqich kodi misol
numeric_cols = ['NetMigrationRateper1000people', 'TotalNetMigrationabsolutenumber',
                'InternationalMigrantStockofpopulation', 'RefugeePopulation',
                'PersonalRemittancesofGDP', 'PersonalRemittancescurrentUSD']

for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')  # NaN qiymatlar hosil bo‘lsa e'tibor beramiz

# 4-bosqich: yil bo‘yicha ko‘rsatkichlarni tahlil qilish
df_sorted = df.sort_values('Year', ascending=False)
print(df_sorted.head())
# Out:
#    Year  NetMigrationRateper1000people  TotalNetMigrationabsolutenumber  \
# 0  2023                          -6004                                0
# 1  2022                          -5007                                0
# 2  2021                          -9205                                0
# 3  2020                          -9208                                0
# 4  2019                          -9341                                0
#
#    InternationalMigrantStockofpopulation  RefugeePopulation  \
# 0                                    0.0               9405
# 1                                    0.0              13026
# 2                                    0.0              13032
# 3                                    0.0                 13
# 4                                    0.0                 13
#
#    PersonalRemittancesofGDP  PersonalRemittancescurrentUSD
# 0                 13.946882                   1.416888e+10
# ...

# %%
import os

# Git konfiguratsiyasi
# !git config --global user.name "nomozovkn"
# !git config --global user.email "kamoliddinnomozov2606@gmail.com"

# Tokenni o'zgaruvchiga saqlaymiz
os.environ['GITHUB_TOKEN'] = 'ghp_11BMXHUZQ0O4aHh3pW7NqJ_U8bNZWrpIDWoyEa4XggDSQ3yNjcIeCu07MJDU6oR70353HUCV7ME0mTSe1U'

# Repository'ni token bilan klonlash
# !git clone https://nomozovkn:{os.environ['GITHUB_TOKEN']}@github.com/nomozovkn/Colab.git
# %cd Colab

# README.md faylini yangilash
# !echo "\nColab ishlarimiz README.md ga qo‘shildi." >> README.md

# O'zgartirishlarni commit qilish
# !git add README.md
# !git commit -m "Update README from Colab"

# Token bilan push qilish
# !git push https://nomozovkn:{os.environ['GITHUB_TOKEN']}@github.com/nomozovkn/Colab.git main
# Out:
# Cloning into 'Colab'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/Colab/Colab/Colab/Colab/Colab/Colab/Colab/Colab/Colab/Colab/Colab/Colab
# [main 2f7e0fa] Update README from Colab
#  1 file changed, 1 insertion(+)
# remote: {"auth_status":"auth_error","body":"Invalid username or token. Password authentication is not supported for Git operations."}
# fatal: Authentication failed for 'https://github.com/nomozovkn/Colab.git/'

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-21c983a3-682a-45ca-a745-02b78658d130" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21c983a3-682a-45ca-a745-02b78658d130">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir())
import xml.etree.ElementTree as ET

# Faylni ochish
tree = ET.parse("1-013-0032.xml")
root = tree.getroot()

# Birinchi 5 ta elementni ko‘rish
for child in root[:5]:
    print(child.tag, child.attrib)

    import xml.etree.ElementTree as ET
import pandas as pd

# XML faylni ochamiz
tree = ET.parse("1-013-0032.xml")
root = tree.getroot()

rows = []
for record in root.findall(".//record"):   # <record> elementlarini izlaymiz
    row = {}
    for field in record:
        row[field.tag] = field.text
    rows.append(row)

# DataFrame ga o‘tkazamiz
df = pd.DataFrame(rows)
print(df.head())


import xml.etree.ElementTree as ET

tree = ET.parse("1-013-0032.xml")
root = tree.getroot()

# Birinchi 30 qatorni chop etamiz
for elem in root.iter():
    print(elem.tag, elem.attrib, elem.text[:50] if elem.text else "")
    break  # agar hammasini chiqarib yubormasin desang, break'ni olib tashlama

import xml.etree.ElementTree as ET

tree = ET.parse("1-013-0032.xml")
root = tree.getroot()

# Faqat birinchi 50 elementni ko‘rsatamiz
for i, elem in enumerate(root.iter()):
    print(elem.tag, elem.attrib, elem.text)
    if i > 50:  # juda uzun chiqmasligi uchun
        break


        import xml.etree.ElementTree as ET
import pandas as pd

# XML faylni ochamiz
tree = ET.parse("1-013-0032.xml")
root = tree.getroot()

data = []
for table in root.findall("table"):
    row = {}
    for child in table:
        row[child.tag] = child.text
    data.append(row)

# DataFrame yaratamiz
df = pd.DataFrame(data)

# Raqamli ustunlarni float/int ga aylantiramiz
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors="ignore")

print(df.head())
# Out:
# ['.config', 'UNdata_Export_20250927_202233364 (1).zip', 'UNdata_Export_20250927_202233364.zip', '1-013-0032.xml', 'sample_data']
# table {}
# table {}
# table {}
# table {}
# table {}
# Empty DataFrame
# Columns: []
# Index: []
# ArrayOfTable {}
# ArrayOfTable {} None
# table {} None
# Year {} 2023
# NetMigrationRateper1000people {} -6004
# TotalNetMigrationabsolutenumber {} 0
# InternationalMigrantStockofpopulation {} 0
# RefugeePopulation {} 9405
# PersonalRemittancesofGDP {} 13.9468815680259
# PersonalRemittancescurrentUSD {} 14168883803.2474
# table {} None
# Year {} 2022
# NetMigrationRateper1000people {} -5007
# TotalNetMigrationabsolutenumber {} 0
# InternationalMigrantStockofpopulation {} 0
# RefugeePopulation {} 13026
# PersonalRemittancesofGDP {} 17.2173418207715
# PersonalRemittancescurrentUSD {} 15512123643.7067
# table {} None
# Year {} 2021
# NetMigrationRateper1000people {} -9205
# TotalNetMigrationabsolutenumber {} 0
# InternationalMigrantStockofpopulation {} 0
# ...

# %%
df.to_excel("uzbekistan_migration.xlsx", index=False)


import matplotlib.pyplot as plt

plt.plot(df["Year"], df["PersonalRemittancescurrentUSD"], marker="o")
plt.title("Uzbekistan – Pul o‘tkazmalari (USD)")
plt.xlabel("Yil")
plt.ylabel("USD")
plt.grid(True)
plt.show()

# %% [markdown]
# O‘zbekiston aholisi va migratsiya statistikasi (2017–2023)
#
# UNData va O‘zStat qo‘mitasi ma’lumotlariga ko‘ra, O‘zbekistonda 2017–2023 yillar davomida migratsiya salbiy ko‘rsatkichga ega bo‘ldi. Bu esa mamlakatdan ko‘chib ketayotganlarning qaytib kelayotganlardan ko‘pligini anglatadi. Masalan, 2017-yilda 1000 kishiga to‘g‘ri keladigan sof migratsiya darajasi -13 352 bo‘lgan bo‘lsa, 2023-yilga kelib bu ko‘rsatkich -6 004 gacha kamaygan.
#
# Pul o‘tkazmalari (remittances) esa ushbu davrda barqaror o‘sib bordi. 2021-yilda 9,27 mlrd AQSH dollari bo‘lgan shaxsiy pul o‘tkazmalari 2022-yilda 15,5 mlrd dollarga, 2023-yilda esa 14,1 mlrd dollarga yetgan. Bu o‘z navbatida O‘zbekiston YaIMining muhim qismini tashkil qiladi (2022-yilda 17,2 %).
#
# Qochqinlar soni ham davr mobaynida o‘zgarib turgan: 2017–2019 yillarda 13 kishi atrofida bo‘lgan bo‘lsa, 2022-yilda 13 mingdan ortiq, 2023-yilda esa 9,4 ming kishini tashkil qilgan.
#
# Xulosa
#
# Migratsiya salbiy bo‘lib qolmoqda, ammo oxirgi yillarda uning miqyosi qisqarib bormoqda.
#
# Pul o‘tkazmalari yil sayin ortib, mamlakat iqtisodiy hayotida muhim o‘rin egallamoqda.
#
# Qochqinlar sonida keskin o‘zgarishlar kuzatilgan.

# %% [markdown]
# ## Xulosa
#
# 📌 2017–2023 yillarda O‘zbekistonda migratsiya salbiy ko‘rsatkichda bo‘lib qolmoqda.
# 📌 Pul o‘tkazmalari hajmi esa yildan-yilga ortib, mamlakat iqtisodiyotida muhim o‘rin egallamoqda.
# 📌 Qochqinlar soni keskin o‘zgarishlarga ega bo‘lib, ayrim yillarda keskin ko‘paygan.
#
# Umuman olganda, ma’lumotlar O‘zbekiston aholisi va migratsiya jarayonlari mamlakat iqtisodiy rivojlanishiga bevosita ta’sir ko‘rsatayotganini ko‘rsatadi.

# %% [markdown]
# 6- Bosqich:Bu bosqichda biz O‘zbekistonning yillar bo‘yicha Net Migration Rate (1000 aholiga nisbatan) ko‘rsatkichini tahlil qilamiz.
#
# Bu ko‘rsatkich aholi soniga nisbatan ko‘chib kelgan va ketgan odamlar farqini bildiradi.
#
# Agar qiymat manfiy bo‘lsa → odamlar mamlakatdan ko‘proq chiqib ketganini anglatadi.
#
# Agar qiymat musbat bo‘lsa → odamlar mamlakatga ko‘proq kirib kelganini anglatadi.
#
# Shu sababli, grafik chizib, yillar bo‘yicha qanday o‘zgarish bo‘lganini ko‘ramiz.

# %%
import matplotlib.pyplot as plt

# NetMigrationRate per 1000 people ni grafik ko‘rsatamiz
plt.figure(figsize=(10,6))
plt.plot(df["Year"], df["NetMigrationRateper1000people"], marker="o", color="red")
plt.title("O‘zbekiston: Net Migration Rate (1000 aholiga nisbatan)")
plt.xlabel("Yil")
plt.ylabel("Migratsiya ko‘rsatkichi")
plt.grid(True)
plt.show()

# %% [markdown]
# 7-Bosqich: Bu bosqichda biz:
#
# DataFrame’ning ustunlari, qatorlari sonini ko‘ramiz.
#
# Har bir ustun tipini (datatype) tekshiramiz.
#
# Birinchi 5–10 ta qatorni chiqaramiz.
#
# Null (bo‘sh) qiymatlar bormi yo‘qmi tekshiramiz.
#
# Aholi soni (population) va migratsiya ma’lumotlari uchun asosiy statistikani chiqaramiz (mean, min, max, std).

# %%
import pandas as pd

# XML fayldan DataFrame o‘qish
df = pd.read_xml("1-013-0032.xml")

# 1. Jadval hajmi
print("📌 Jadval o‘lchami (qator, ustun):", df.shape)

# 2. Ustunlarning nomlari va tiplari
print("\n📌 Ustunlar va tiplari:")
print(df.dtypes)

# 3. Birinchi 5 ta qator
print("\n📌 Birinchi 5 ta qator:")
print(df.head())

# 4. Null qiymatlar soni
print("\n📌 Har bir ustundagi bo‘sh qiymatlar soni:")
print(df.isnull().sum())

# 5. Statistik tahlil (faqat sonli ustunlar uchun)
print("\n📌 Sonli ustunlar statistikasi:")
print(df.describe())
# Out:
# 📌 Jadval o‘lchami (qator, ustun): (64, 7)
#
# 📌 Ustunlar va tiplari:
# Year                                       int64
# NetMigrationRateper1000people              int64
# TotalNetMigrationabsolutenumber            int64
# InternationalMigrantStockofpopulation    float64
# RefugeePopulation                          int64
# PersonalRemittancesofGDP                 float64
# PersonalRemittancescurrentUSD            float64
# dtype: object
#
# 📌 Birinchi 5 ta qator:
#    Year  NetMigrationRateper1000people  TotalNetMigrationabsolutenumber  \
# 0  2023                          -6004                                0
# 1  2022                          -5007                                0
# 2  2021                          -9205                                0
# 3  2020                          -9208                                0
# 4  2019                          -9341                                0
#
#    InternationalMigrantStockofpopulation  RefugeePopulation  \
# ...

# %% [markdown]
# 8-Bosqich:Bu bosqichda biz jadvaldagi asosiy ustunlarni grafik ko‘rinishda tahlil qilamiz:
#
# Yillar bo‘yicha grafik chizamiz.
#
# Masalan:
#
# PersonalRemittancesofGDP (remittances/GDP) trendi
#
# RefugeePopulation o‘zgarishi
#
# NetMigrationRateper1000people grafigi
#
# Bu orqali ma’lumotlarni ko‘z bilan tahlil qilish oson bo‘ladi.

# %%
import matplotlib.pyplot as plt

# Jadvalni yillar bo‘yicha tartiblaymiz
df_sorted = df.sort_values("Year")

# 1. Remittances of GDP trendi
plt.figure(figsize=(10,5))
plt.plot(df_sorted["Year"], df_sorted["PersonalRemittancesofGDP"], marker="o")
plt.title("Personal Remittances of GDP (%)")
plt.xlabel("Year")
plt.ylabel("Remittances (% of GDP)")
plt.grid(True)
plt.show()

# 2. Refugee Population trendi
plt.figure(figsize=(10,5))
plt.plot(df_sorted["Year"], df_sorted["RefugeePopulation"], marker="s", color="red")
plt.title("Refugee Population over Years")
plt.xlabel("Year")
plt.ylabel("Refugee Population")
plt.grid(True)
plt.show()

# 3. Net Migration Rate trendi
plt.figure(figsize=(10,5))
plt.plot(df_sorted["Year"], df_sorted["NetMigrationRateper1000people"], marker="^", color="green")
plt.title("Net Migration Rate (per 1000 people)")
plt.xlabel("Year")
plt.ylabel("Net Migration Rate")
plt.grid(True)
plt.show()

# %% [markdown]
# 9-bosqich — Korrelyatsiya va bog‘liqlik tahlili
# Bu bosqichda ma’lumotlar orasidagi bog‘liqlik darajasini tekshiramiz:
#
# Masalan, Remittances (pul jo‘natmalar) va Refugee Population o‘rtasida qanday aloqa bor?
#
# Yoki Migration rate bilan Remittances of GDP o‘rtasida korrelyatsiya mavjudmi?
#
# Buni tushunish uchun:
#
# Korrelyatsiya matritsasi chizamiz.
#
# Uni heatmap orqali ko‘rsatamiz.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Faqat sonli ustunlarni olish
numeric_df = df.select_dtypes(include=["float64", "int64"])

# Korrelyatsiya matritsasi
corr = numeric_df.corr()

# Heatmap chizish
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Korrelyatsiya matritsasi")
plt.show()

# %% [markdown]
# 10-bosqich — Deskriptiv (umumiy) statistika
# Bu bosqichda ma’lumotlarni qisqa tarzda tahlil qilamiz:
#
# O‘rtacha qiymat (mean) – ustunning o‘rtacha darajasi.
#
# Median (me’yori) – o‘rtadagi qiymat.
#
# Min / Max – eng kichik va eng katta qiymat.
#
# Standard deviation (std) – qiymatlar qanchalik tarqoq ekanini ko‘rsatadi.
#
# Shunday qilib, biz ma’lumotlarimizni umumiy ko‘rinishda tushunib olamiz.

# %%
# Deskriptiv statistika
stats = df.describe()

print("📊 Deskriptiv statistika:")
print(stats)

# Faqat asosiy ko'rsatkichlarni chiqarish
print("\nAsosiy ko'rsatkichlar:")
print("O'rtacha remittances of GDP:", df["PersonalRemittancesofGDP"].mean())
print("Eng katta refugee population:", df["RefugeePopulation"].max())
print("Migration rate min:", df["NetMigrationRateper1000people"].min())
# Out:
# 📊 Deskriptiv statistika:
#               Year  NetMigrationRateper1000people  \
# count    64.000000                      64.000000
# mean   1991.500000                   -2119.578125
# std      18.618987                   38152.904883
# min    1960.000000                  -73478.000000
# 25%    1975.750000                  -29097.250000
# 50%    1991.500000                   -9206.500000
# 75%    2007.250000                   27006.750000
# max    2023.000000                   77914.000000
#
#        TotalNetMigrationabsolutenumber  InternationalMigrantStockofpopulation  \
# count                     6.400000e+01                              64.000000
# mean                      1.295503e+05                               0.529681
# std                       4.091769e+05                               1.714794
# min                       0.000000e+00                               0.000000
# 25%                       0.000000e+00                               0.000000
# ...

# %% [markdown]
# 11-bosqich — Trend tahlili (vaqt bo‘yicha o‘zgarishlar)
# Bu bosqichda yillar bo‘yicha ma’lumotlarning qanday o‘zgarib borganini grafikda ko‘rsatamiz. Masalan:
#
# Migratsiya ko‘rsatkichi yildan yilga qanday o‘zgaradi?
#
# Remittances (chet eldan yuborilgan pul) qachon ko‘p yoki kam bo‘lgan?
#
# Refugee population (qochqinlar soni) qanday dinamikaga ega?
#
# Grafik orqali o‘zgarishlarni ko‘rish ancha qulayroq bo‘ladi.

# %%
import matplotlib.pyplot as plt

# Grafik chizish
plt.figure(figsize=(12,6))

plt.plot(df["Year"], df["NetMigrationRateper1000people"], marker="o", label="Net Migration Rate (/1000)")
plt.plot(df["Year"], df["PersonalRemittancesofGDP"], marker="s", label="Remittances (% of GDP)")
plt.plot(df["Year"], df["RefugeePopulation"], marker="^", label="Refugee Population")

plt.title("O‘zbekiston migratsiya va remittances statistikasi (trend)")
plt.xlabel("Yil")
plt.ylabel("Qiymatlar")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 12-bosqich — Korelatsiya tahlili
# Bu bosqichda biz ustunlar orasidagi bog‘liqlikni (korelatsiya) hisoblaymiz. Masalan:
#
# Remittances (% of GDP) bilan Net Migration orasida bog‘liqlik bormi?
#
# Refugee population bilan boshqa ko‘rsatkichlar qanday munosabatda?
#
# Korelatsiya jadvali -1 dan +1 gacha qiymatlar beradi:
#
# +1 → kuchli to‘g‘ri bog‘liqlik (birga ortadi).
#
# -1 → kuchli teskari bog‘liqlik (biri oshsa, ikkinchisi kamayadi).
#
# 0 → bog‘liqlik yo‘q.

# %%
import seaborn as sns

# Faqat sonli ustunlarni tanlaymiz
numeric_df = df.select_dtypes(include=["number"])

# Korelatsiya matritsasi
corr = numeric_df.corr()

# Jadval ko‘rish
print("Korelatsiya jadvali:")
print(corr)

# Issiqlik xarita (heatmap)
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("O‘zbekiston statistik ko‘rsatkichlari orasidagi korelatsiya")
plt.show()
# Out:
# Korelatsiya jadvali:
#                                            Year  \
# Year                                   1.000000
# NetMigrationRateper1000people         -0.712954
# TotalNetMigrationabsolutenumber        0.172501
# InternationalMigrantStockofpopulation  0.150447
# RefugeePopulation                      0.277576
# PersonalRemittancesofGDP               0.780470
# PersonalRemittancescurrentUSD          0.725467
#
#                                        NetMigrationRateper1000people  \
# Year                                                       -0.712954
# NetMigrationRateper1000people                               1.000000
# TotalNetMigrationabsolutenumber                            -0.361371
# InternationalMigrantStockofpopulation                      -0.371959
# RefugeePopulation                                          -0.418864
# PersonalRemittancesofGDP                                   -0.220977
# PersonalRemittancescurrentUSD                              -0.154445
# ...

# %% [markdown]
# 13-bosqich — Bashorat qilish (Forecast)
# Bu bosqichda mavjud ma’lumotlar asosida kelajak uchun oddiy bashorat qilamiz. Masalan, 2024–2026 yillar uchun Net Migration va Remittances qiymatlarini oldindan taxmin qilish.
#
# Oddiy usul sifatida Linear Regression (chiziqli regressiya) modelidan foydalanamiz. Bu usul yordamida tarixiy trend asosida kelajak qiymatlarini hisoblaymiz.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Faqat yillar va remittances ustunini olamiz
X = df["Year"].values.reshape(-1, 1)
y = df["PersonalRemittancesofGDP"].values

# Modelni o‘qitamiz
model = LinearRegression()
model.fit(X, y)

# Kelajak yillar
future_years = np.array([2024, 2025, 2026]).reshape(-1, 1)
predictions = model.predict(future_years)

# Natijani chiqaramiz
for year, pred in zip(future_years.flatten(), predictions):
    print(f"{year} yil uchun bashorat qilingan Remittances (% of GDP): {pred:.2f}")

# Grafik ko‘rsatamiz
plt.figure(figsize=(10,6))
plt.scatter(X, y, color="blue", label="Haqiqiy ma’lumotlar")
plt.plot(X, model.predict(X), color="red", label="Regression chizig‘i")
plt.scatter(future_years, predictions, color="green", marker="x", s=100, label="Bashorat qilingan nuqtalar")

plt.title("Remittances (% of GDP) bashorati (2024–2026)")
plt.xlabel("Yil")
plt.ylabel("Remittances (% of GDP)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 2024 yil uchun bashorat qilingan Remittances (% of GDP): 9.40
# 2025 yil uchun bashorat qilingan Remittances (% of GDP): 9.60
# 2026 yil uchun bashorat qilingan Remittances (% of GDP): 9.80

# %% [markdown]
# 14-bosqich — Xulosa yozish
# O‘zbekiston aholisi va migratsiya statistikasi tahlilidan quyidagi xulosalarni olish mumkin:
#
# Net Migration (migratsiya ko‘rsatkichi) ko‘p yillarda manfiy bo‘lgan, ya’ni mamlakatdan chiqib ketayotganlar kirib kelayotganlardan ko‘proq.
#
# Remittances (chet eldan yuborilgan pul o‘tkazmalari) mamlakat iqtisodiyotida juda katta ahamiyatga ega. So‘nggi yillarda ularning YaIMdagi ulushi 10–17% atrofida bo‘lib kelmoqda.
#
# Refugee population (qochqinlar soni) ma’lum yillarda o‘sib, keyinchalik kamaygan. Bu ko‘rsatkich siyosiy va iqtisodiy omillarga bog‘liq.
#
# Korelatsiya tahlili shuni ko‘rsatdiki, remittances va migratsiya ko‘rsatkichlari o‘rtasida ma’lum bog‘liqlik mavjud, ya’ni odamlarning tashqariga chiqishi ularning moliyaviy pul o‘tkazmalarida aks etadi.
#
# Oddiy regressiya bashorati shuni ko‘rsatdiki, agar hozirgi trend davom etsa, yaqin yillarda remittances darajasi biroz pasayishi yoki barqarorlashishi mumkin.
#
# 🔎 Umuman olganda, O‘zbekiston uchun migratsiya va pul o‘tkazmalari iqtisodiy taraqqiyot va ijtimoiy hayotda muhim rol o‘ynaydi.

# %% [markdown]
# 15-bosqich — Hisobotni faylga chiqarish (PDF yoki DOCX)
# Bu bosqichda biz Colabda qilgan ishlarimizni PDF yoki DOCX hisobot ko‘rinishida saqlaymiz.
# Hisobotga quyidagilar kiritiladi:
#
# Jadval (asosiy ma’lumotlar)
#
# Grafiklar (migratsiya, remittances, trendlar)
#
# Korelatsiya tahlili
#
# Xulosa matni
#
# Bu bilan ishni rasmiy hisobot shaklida topshirish oson bo‘ladi.

# %% [markdown]
# Umumiy xulosa
# Ma’lumotlarni tayyorlash va yuklash
#
# UNdata saytidan O‘zbekiston migratsiya va remittances (pul jo‘natmalari) ma’lumotlarini XML formatda yukladik.
#
# XML faylni Colabga yuklab, Python yordamida ochdik.
#
# Ma’lumotlarni o‘qish va tozalash
#
# XML fayldagi kerakli table va ArrayOfTable elementlarini ajratdik.
#
# Ma’lumotlarni DataFrame shaklida jamladik.
#
# Yillar bo‘yicha NetMigrationRate, RefugeePopulation, PersonalRemittances kabi ustunlarni tozaladik va raqamli formatga o‘tkazdik.
#
# Ma’lumotlarni tahlil qilish
#
# Har bir yil bo‘yicha aholi chiqishi (Net Migration) va pul jo‘natmalari (Personal Remittances) ko‘rsatkichlarini ajratdik.
#
# So‘nggi yillarda Net Migration manfiy, ya’ni aholining chiqishi davom etayotganini ko‘rdik.
#
# Personal Remittances YaIMga sezilarli ta’sir ko‘rsatmoqda (10–17%).
#
# Natijalarni saqlash
#
# Tozalangan va tahlil qilingan ma’lumotlarni CSV yoki PDF shaklida saqladik.
#
# Keyingi bosqichlarda vizual grafiklar bilan PDF hisobotini yanada tushunarli qilish mumkin.
#
# Trendlar va kuzatuvlar
#
# 2017–2023 yillar davomida aholi chiqishi yuqori bo‘lgan, ammo oxirgi yillarda biroz kamaygan.
#
# Pul jo‘natmalari barqaror o‘sishda bo‘lib, iqtisodiy barqarorlikka hissa qo‘shadi.
#
# Refugee Population raqamlari nisbatan kichik, lekin yil sayin farq qiladi.
